# %%
import matplotlib.pyplot as plt 

x = [ "day1" , "day2" , "day3" , "day4" , "day5"]
y = [ 200 , 400 , 500 , 800 , 999 ] 
y1 = [ 100 , 500 , 700 , 300 , 600 ] 

plt.plot(x,y , marker = "o" , ls="-" , label = "Data1" , color = "red" , alpha=0.5 )
plt.plot(x,y1 , marker = "o" , ls="-" , label = "Data2" , color = "blue")
plt.legend()
plt.show()

# %%
import pandas as pd 
import matplotlib.pyplot as plt 

data = pd.read_excel(r"C:\Users\WIN10\Desktop\DataAnalyics\employee_data.xlsx")
pd.DataFrame(data)
print(data)

group_by = data.groupby("Department")["Salary"].sum()
plt.plot(data["Employee ID"],data["Salary"])
plt.plot(group_by.index , group_by.values)
plt.show()
# Out:
#    Employee ID               Name   Department Joining Date  Salary  \
# 0        E1000       Norma Fisher    Marketing   2017-02-10  119651
# 1        E1001     Jorge Sullivan    Marketing   2017-10-19   73279
# 2        E1002    Elizabeth Woods           HR   2018-02-16   91884
# 3        E1003       Susan Wagner  Engineering   2016-03-29  103375
# 4        E1004   Peter Montgomery        Sales   2016-12-12   43199
# 5        E1005   Theodore Mcgrath    Marketing   2024-10-12   76372
# 6        E1006  Stephanie Collins    Marketing   2022-03-29   86907
# 7        E1007   Stephanie Sutton  Engineering   2024-07-04   71444
# 8        E1008     Brian Hamilton    Marketing   2020-04-09  110070
# 9        E1009         Susan Levy  Engineering   2024-06-17  113941
# 10       E1010         Sean Green        Sales   2019-08-04   56801
# 11       E1011     Kimberly Smith      Finance   2019-03-31  102420
# 12       E1012   Jennifer Summers        Sales   2022-09-20   92522
# ...

# %%
import matplotlib.pyplot as plt

# Sample data
x = [1, 2, 3, 4, 5]
y = [10, 20, 25, 30, 40]

# Create line chart
plt.plot(x, y, marker='o', linestyle='-', color='b', label='Sales')

# Add labels and title
plt.xlabel("Time (Days)")
plt.ylabel("Sales (in $1000)")
plt.title("Sales Over Time")
plt.legend()

# Show the chart
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Months of the year
months = [
    "Jan", "Feb", "Mar", "Apr", "May", "Jun",
    "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"
]

# Sample monthly revenue (in $1000)
revenue = [50, 55, 60, 65, 58, 75, 80, 85, 78, 90, 95, 100]

# Create the line chart
plt.figure(figsize=(10, 6))
plt.plot(months, revenue, marker='o', linestyle='-', color='green', label='Revenue')

# Add labels and title
plt.title("Monthly Revenue in 2025", fontsize=16)
plt.xlabel("Month", fontsize=12)
plt.ylabel("Revenue (in $1000)", fontsize=12)
plt.grid(True)
plt.legend()

# Highlight max and min revenue
max_value = max(revenue)
min_value = min(revenue)
max_month = months[revenue.index(max_value)]
min_month = months[revenue.index(min_value)]

plt.annotate(f'Max: {max_value}k', xy=(max_month, max_value), xytext=(max_month, max_value + 5),
             arrowprops=dict(facecolor='green', shrink=0.05))
plt.annotate(f'Min: {min_value}k', xy=(min_month, min_value), xytext=(min_month, min_value - 10),
             arrowprops=dict(facecolor='red', shrink=0.05))

# Save the chart as an image
plt.savefig("monthly_revenue_chart.png", dpi=300)

# Show the chart
plt.show()
