# %%
import matplotlib.pyplot as plt 

l = [ 10 , 45, 78 , 56 , 45 , 23 , 12 , 10 , 45 , 78 , 87 , 95 ]
plt.violinplot(l , showmedians=True)

plt.show()

# %%
import pandas as pd 
import matplotlib.pyplot as plt 

data = pd.read_excel(r"C:\Users\WIN10\Desktop\DataAnalyics\employee_data.xlsx")
df = pd.DataFrame(data)

plt.violinplot(df["Salary"] , showmedians= True)
plt.show()
